# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
test_data = pd.read_csv('/home/sukant/datasets/mnist_csv/mnist_test.csv')
train_data = pd.read_csv('/home/sukant/datasets/mnist_csv/mnist_train.csv')

# %%
test_data = np.array(test_data)
train_data = np.array(train_data)


m , n =   train_data.shape
print (m,n ) 


# git check 
layer_dims = 784
# Out:
# 60000 785

# %% [markdown]
# Neuron --> take ip and generate op , op depend on the imput and the params
#  , neurons are degined here using a sigmoid funtion (which gives an op of 1 if its positive and 0 if negative )

# %% [markdown]
#  Forward prop --> the nn generating an op for a  given ip

# %% [markdown]
# Prediction --> the op given by the last layer

# %% [markdown]
# Cost/loss funtion --> the diffference between the truth and the predicted value

# %% [markdown]
# Algo like grdient descent and stochastic gradient descnent are used to update the params of the nn to minimize the cost funtion.

# %%
def init_params(ip_size , hl_size ,op_size) :

    w1 = np.random.randn(hl_size, ip_size) * 0.01
    w2 = np.random.randn(op_size, hl_size) * 0.01 

    b1 = np.random.randn (hl_size)
    b2 = np.random.randn (op_size)

    return w1 , w2 , b1, b2

# %%
def ReLU(Z) :
    if Z >  0 :
        return Z 
    else :
        return 0

# %%
def softmax(Z):
    sigma = np.exp(z) / sum(np.exp(Z))
    return sigma

# %%
def forward_prop(w1 ,w2 , b1, b2, X) :

    # A0 = X 
    
    # A1 ip layer matrix 

    # Z1 = w1 . X + b1  
    Z1 = np.dot(w1,X) + b1 
    
    # ReLU --> activation function 

    A1 = ReLU(Z1) # Either 0 or the nummber itself 

    # Z2  = w2 . A1 + b2 
    Z2 = np.dot(w2,A1) + b2

    # Softmax 
    A2 = softmax(Z2) # Between 0 and 1 

    return Z1 ,  A1  , Z2 , A2

# %%
def Relu_deriv(Z) : 
    return

# %% [markdown]
# def ReLU() :
#
#
# def softmax() :
#
# def forward_prop () :
#
# def ReLU_deriv () :
#
# def one_hot() :
#
# def backwarrd_prop () :
#
# def update_params() :

# %%
# An algo to optimse the paramaters (i.e. weights and biases )

# Weights  are like the strength of a connection between two neurons and
# biases is some indication wether the newron is active or inactive.
# Y being the final op (Digit here) 

# How did the  gradient descent happen ??

def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    one_hot_Y[np.arange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y):

    one_hot_Y = one_hot(Y)
    dZ2 = A2 - one_hot_Y # How  much the second layer is off by

    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2)
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)

    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1)

    return dW1, db1, dW2, db2

# %% [markdown]
# ![Chanin Rule .png](<attachment:Chanin Rule .png>)

# %% [markdown]
# Gradient Descent vid -
#
# GD - repeatedly nudging the an ip of a funtion with some multiple of the negative gradient.
#
# w  = w -  a. d(Z)/dw
#
# Gradient vector --> has the relative importance of each weight and biase
#
#                     " NEURONS that fire togethwe,  wire together. "
#
# Cost funtion : takes in as ip the weights and biases of the nn and spits out how bad those weights and biases are.
#
# "Learning" --> minimising the cost function

# %%
def update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1    
    W2 = W2 - alpha * dW2  
    b2 = b2 - alpha * db2    
    return W1, b1, W2, b2
